# %% [markdown]
# # Input Ranges (OUT OF DATE – NEED TO UPDATE)
#
# | ID      | Name                | Range / Units                |
# |---------|---------------------|------------------------------|
# | FBFM40  | fuel_model          | specific(fuel model code)    |
# | X_IGN   | x_ignition          | [-960, 960] (meters)         |
# | Y_IGN   | y_ignition          | [-960, 960] (meters)         |
# | SLP     | slope               | [0, 45] (degrees)            |
# | ASP     | aspect              | [0, 360] (degrees)           |
# | WS      | wind_speed          | [0, 30] (mph)                |
# | WD      | wind_direction      | [0, 360] (degrees)           |
# | M1      | m1_moisture         | [2, 40] (%)                  |
# | M10     | m10_moisture        | [2, 40] (%)                  |
# | M100    | m100_moisture       | [2, 40] (%)                  |
# | CC      | canopy_cover        | [0, 100] (%)                 |
# | CH      | canopy_height       | [0, 5] (integer, 10m units)  |
# | CBH     | canopy_base_height  | [0, min(3, canopy_height)] (integer, 10m units) |
# | CBD     | canopy_bulk_density | [0, 40] (100 kg/m³)          |
# | MLH     | live_herbaceous     | [30, 100] (%)                |
# | MLW     | live_woody          | [30, 100] (%)                |
# | DEM     | elevation           | [0, 0] (meters, constant)    |
#
# Elevation, adjustment factor, and initial phi value all held constant

# %%
import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
from matplotlib import cm

import analysis_fcns

import glob
import rasterio

# get the num of cases in ./cases
cases = glob.glob('../cases/*')
num_cases = len(cases)

# %%
analysis_fcns.print_all_cases_info(num_cases)
# Out:
# Case 1 path: ../cases/case_1
# ../cases/case_1/flin_0000001_0259273.tif: shape=(128, 128), min=-9999.0, max=732.6360473632812
# ../cases/case_1/time_of_arrival_0000001_0259273.tif: shape=(128, 128), min=-9999.0, max=259273.46875
# ../cases/case_1/vs_0000001_0259273.tif: shape=(128, 128), min=-9999.0, max=42.20743179321289
# Case 2 path: ../cases/case_2
# ../cases/case_2/flin_0000001_0259689.tif: shape=(128, 128), min=-9999.0, max=12223.14453125
# ../cases/case_2/time_of_arrival_0000001_0259689.tif: shape=(128, 128), min=-9999.0, max=51838.80859375
# ../cases/case_2/vs_0000001_0259689.tif: shape=(128, 128), min=-9999.0, max=62.7170524597168
# Case 3 path: ../cases/case_3
# ../cases/case_3/flin_0000001_0259980.tif: shape=(128, 128), min=-9999.0, max=0.8401966691017151
# ../cases/case_3/time_of_arrival_0000001_0259980.tif: shape=(128, 128), min=-9999.0, max=259380.0
# ../cases/case_3/vs_0000001_0259980.tif: shape=(128, 128), min=-9999.0, max=0.17784595489501953
# Case 4 path: ../cases/case_4
# ../cases/case_4/flin_0000001_0259980.tif: shape=(128, 128), min=-9999.0, max=26.231765747070312
# ../cases/case_4/time_of_arrival_0000001_0259980.tif: shape=(128, 128), min=-9999.0, max=259980.0
# ../cases/case_4/vs_0000001_0259980.tif: shape=(128, 128), min=-9999.0, max=4.072534084320068
# Case 5 path: ../cases/case_5

# %%
analysis_fcns.plot_case(2)

# %%
patterns = ["flin_*.tif", "time_of_arrival_*.tif", "vs_*.tif"]
analysis_fcns.plot_all_cases_raster('flin_*.tif', num_cases)
# Out:
# Plotting all cases for raster pattern: flin_*.tif

# %%
analysis_fcns.plot_input_distribution()
# Out:
# Input parameters distribution from ../configuration/input_tracking.txt:
#             run        xign        yign        fuel        slp         asp  \
# count  5.000000    5.000000    5.000000    5.000000   5.000000    5.000000
# mean   2.000000 -232.160000  178.840000  121.400000  13.600000  143.800000
# std    1.581139  367.077625  618.772356   17.227884  14.380542   41.583651
# min    0.000000 -573.300000 -343.900000  105.000000   1.000000  106.000000
# 25%    1.000000 -487.000000 -294.300000  109.000000   2.000000  108.000000
# 50%    2.000000 -428.600000 -172.800000  121.000000   9.000000  144.000000
# 75%    3.000000  113.500000  814.900000  123.000000  21.000000  153.000000
# max    4.000000  214.600000  890.300000  149.000000  35.000000  208.000000
#
#               ws          wd        m1       m10      m100   cc   ch  cbh  \
# count   5.000000    5.000000   5.00000   5.00000   5.00000  5.0  5.0  5.0
# mean    9.780000  182.080000   8.40000   9.40000  10.40000  0.0  0.0  0.0
# std     7.805895  116.521552   2.50998   2.50998   2.50998  0.0  0.0  0.0
# min     1.400000   64.500000   6.00000   7.00000   8.00000  0.0  0.0  0.0
# 25%     2.300000  105.100000   6.00000   7.00000   8.00000  0.0  0.0  0.0
# 50%    11.600000  134.300000   9.00000  10.00000  11.00000  0.0  0.0  0.0
# 75%    14.000000  265.100000   9.00000  10.00000  11.00000  0.0  0.0  0.0
# max    19.600000  341.400000  12.00000  13.00000  14.00000  0.0  0.0  0.0
#
#        cbd         lhc         lwc     firearea
# count  5.0    5.000000    5.000000     5.000000
# mean   0.0   72.000000  102.000000  1715.060000
# std    0.0   45.497253   45.497253  1532.007377
# min    0.0   30.000000   60.000000    19.800000
# 25%    0.0   30.000000   60.000000   411.700000
# 50%    0.0   60.000000   90.000000  1629.700000
# 75%    0.0  120.000000  150.000000  3094.600000
# max    0.0  120.000000  150.000000  3419.500000

# %%
analysis_fcns.plot_input_vs_run()
# Out:
# Input parameters vs Run number from ../configuration/input_tracking.txt:
#             run        xign        yign        fuel        slp         asp  \
# count  5.000000    5.000000    5.000000    5.000000   5.000000    5.000000
# mean   2.000000 -232.160000  178.840000  121.400000  13.600000  143.800000
# std    1.581139  367.077625  618.772356   17.227884  14.380542   41.583651
# min    0.000000 -573.300000 -343.900000  105.000000   1.000000  106.000000
# 25%    1.000000 -487.000000 -294.300000  109.000000   2.000000  108.000000
# 50%    2.000000 -428.600000 -172.800000  121.000000   9.000000  144.000000
# 75%    3.000000  113.500000  814.900000  123.000000  21.000000  153.000000
# max    4.000000  214.600000  890.300000  149.000000  35.000000  208.000000
#
#               ws          wd        m1       m10      m100   cc   ch  cbh  \
# count   5.000000    5.000000   5.00000   5.00000   5.00000  5.0  5.0  5.0
# mean    9.780000  182.080000   8.40000   9.40000  10.40000  0.0  0.0  0.0
# std     7.805895  116.521552   2.50998   2.50998   2.50998  0.0  0.0  0.0
# min     1.400000   64.500000   6.00000   7.00000   8.00000  0.0  0.0  0.0
# 25%     2.300000  105.100000   6.00000   7.00000   8.00000  0.0  0.0  0.0
# 50%    11.600000  134.300000   9.00000  10.00000  11.00000  0.0  0.0  0.0
# 75%    14.000000  265.100000   9.00000  10.00000  11.00000  0.0  0.0  0.0
# max    19.600000  341.400000  12.00000  13.00000  14.00000  0.0  0.0  0.0
#
#        cbd         lhc         lwc     firearea
# count  5.0    5.000000    5.000000     5.000000
# mean   0.0   72.000000  102.000000  1715.060000
# std    0.0   45.497253   45.497253  1532.007377
# min    0.0   30.000000   60.000000    19.800000
# 25%    0.0   30.000000   60.000000   411.700000
# 50%    0.0   60.000000   90.000000  1629.700000
# 75%    0.0  120.000000  150.000000  3094.600000
# max    0.0  120.000000  150.000000  3419.500000

# %%
# quick check to make sure all of the input parameters are within the expected ranges
analysis_fcns.check_input_ranges()
# Out:
# Checking input parameter ranges from ../configuration/input_tracking.txt:
# Index(['run', 'xign', 'yign', 'fuel', 'slp', 'asp', 'ws', 'wd', 'm1', 'm10',
#        'm100', 'cc', 'ch', 'cbh', 'cbd', 'lhc', 'lwc', 'firearea'],
#       dtype='object')
# fuel values are within the expected range: 101 to 204
# slp values are within the expected range: 0 to 45
# asp values are within the expected range: 0 to 360
# ws values are within the expected range: 0 to 31
# wd values are within the expected range: 0.0 to 360.0
# m1 values are within the expected range: 1.0 to 40.0
# m10 values are within the expected range: 1.0 to 40.0
# m100 values are within the expected range: 1.0 to 40.0
# cc values are within the expected range: 0 to 100
# ch values are within the expected range: 0 to 5
# cbh values are within the expected range: 0 to 2
# cbd values are within the expected range: 0 to 40
# lhc values are within the expected range: 30.0 to 120.0
# lwc values are within the expected range: 60.0 to 150.0
# firearea values are within the expected range: 0 to 3840

# %%
# analyze fire area
analysis_fcns.analyze_fire_area()
# Out:
# Analyzing fire area from ../configuration/input_tracking.txt:
# Fire area statistics:
# count       5.000000
# mean     1715.060000
# std      1532.007377
# min        19.800000
# 25%       411.700000
# 50%      1629.700000
# 75%      3094.600000
# max      3419.500000
# Name: firearea, dtype: float64

# %%
analysis_fcns.fire_area_covariance()
# Out:
# Calculating fire area covariance from ../configuration/input_tracking.txt:
# Covariance between fire area and fuel: 8909.269999999999
# Covariance between fire area and slp: -221.094999999999
# Covariance between fire area and asp: 58210.215000000004
# Covariance between fire area and ws: -592.6460000000004
# Covariance between fire area and wd: 103753.4415
# Covariance between fire area and m1: -179.65500000000014
# Covariance between fire area and m10: -179.65500000000014
# Covariance between fire area and m100: -179.65500000000014
# Covariance between fire area and cc: 0.0
# Covariance between fire area and ch: 0.0
# Covariance between fire area and cbh: 0.0
# Covariance between fire area and cbd: 0.0
# Covariance between fire area and lhc: -54685.65
# Covariance between fire area and lwc: -54685.65
# {'fuel': np.float64(8909.269999999999),
#  'slp': np.float64(-221.094999999999),
#  'asp': np.float64(58210.215000000004),
#  'ws': np.float64(-592.6460000000004),
#  'wd': np.float64(103753.4415),
#  'm1': np.float64(-179.65500000000014),
#  'm10': np.float64(-179.65500000000014),
#  'm100': np.float64(-179.65500000000014),
#  'cc': np.float64(0.0),
#  'ch': np.float64(0.0),
#  'cbh': np.float64(0.0),
#  'cbd': np.float64(0.0),
#  'lhc': np.float64(-54685.65),
#  'lwc': np.float64(-54685.65)}

# %%
analysis_fcns.fire_area_correlation()
# Out:
# Calculating fire area correlation from ../configuration/input_tracking.txt:
# Correlation coefficients with fire area:
# run    -0.719941
# xign    0.933066
# yign   -0.485998
# fuel    0.337559
# slp    -0.010036
# asp     0.913725
# ws     -0.049558
# wd      0.581213
# m1     -0.046721
# m10    -0.046721
# m100   -0.046721
# cc           NaN
# ch           NaN
# cbh          NaN
# cbd          NaN
# lhc    -0.784562
# lwc    -0.784562
# Name: firearea, dtype: float64
# run    -0.719941
# xign    0.933066
# yign   -0.485998
# fuel    0.337559
# slp    -0.010036
# asp     0.913725
# ws     -0.049558
# wd      0.581213
# m1     -0.046721
# m10    -0.046721
# m100   -0.046721
# cc           NaN
# ch           NaN
# cbh          NaN
# cbd          NaN
# lhc    -0.784562
# lwc    -0.784562
# Name: firearea, dtype: float64

# %%
# select 15 cases that have the most fire area
import analysis_fcns
analysis_fcns.plot_top_fire_area_cases(15)
# Out:
# Plotting top 15 cases with the most fire area from ../configuration/input_tracking.txt (excluding fire area == 3419.5):
# Top 15 cases with the most fire area:
#    run  firearea
# 0    0    3094.6
# 1    1    1629.7
# 4    4     411.7
# 3    3      19.8
# ../cases/case_0
# ../cases/case_1
# ../cases/case_4
# ../cases/case_3

# %%
# import analysis_fcns
# analysis_fcns.plot_zero_fire_cases(firearea_threshold=100)

# %%
import analysis_fcns
analysis_fcns.plot_fire_area_vs_inputs()
# Out:
# Plotting fire area against each input parameter from ../configuration/input_tracking.txt:

# %%
import analysis_fcns
analysis_fcns.max_fuel_model_fire_area()
# Out:
# Finding maximum fuel model with fire area from ../configuration/input_tracking.txt:
# Maximum fuel model with fire area > 0: 149
# np.int64(149)

# %%
import analysis_fcns
analysis_fcns.plot_var_dist_for_firearea_underthreshold(variable='fuel',threshold=100)
# Out:
# Plotting distribution of fuel for cases with fire area under 100 from ../configuration/input_tracking.txt:
# Number of cases with fire area <= 100: 1
