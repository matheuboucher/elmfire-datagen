# %%
# !module load OpenMPI
# !module load GDAL

# !export ELMFIRE_BASE_DIR=$TMPDIR/elmfire
# !export ELMFIRE_INSTALL_DIR=$ELMFIRE_BASE_DIR/build/linux/bin
# !export PATH=$PATH:$ELMFIRE_INSTALL_DIR:$ELMFIRE_BASE_DIR/cloudfire

# %%
# !hostname
# !squeue -u $USER  # See if you have active SLURM jobs
# !echo $SLURM_JOB_ID  # Will show job ID if running under SLURM
# Out:
# cx3-2-12.cx3.hpc.ic.ac.uk
# /bin/bash: squeue: command not found

# %%
# !which conda || echo "conda not in PATH"
# !ls ~/miniconda3/bin/conda || ls ~/anaconda3/bin/conda || echo "conda not found in common locations"
# Out:
# /usr/bin/which: no conda in (/opt/jupyter/bin:/rds/easybuild/noarch/apps/software/MATLAB/2023b:/rds/easybuild/noarch/apps/software/MATLAB/2023b/bin:/sbin:/bin:/usr/sbin:/usr/bin:/usr/local/sbin:/opt/pbs/bin)
# conda not in PATH
# ls: cannot access '/rds/general/user/mb3324/home/miniconda3/bin/conda': No such file or directory
# ls: cannot access '/rds/general/user/mb3324/home/anaconda3/bin/conda': No such file or directory
# conda not found in common locations

# %%
# !eval "$(~/miniforge3/bin/conda shell.bash hook)"
# !conda activate pytorch_env
# Out:
# /bin/bash: conda: command not found

# %%
# !conda install -c conda-forge gdal
# Out:
# /bin/bash: conda: command not found

# %%
# !module load GDAL

# %%
# !which gdal_translate
# Out:
# /usr/bin/which: no gdal_translate in (/opt/jupyter/bin:/rds/easybuild/noarch/apps/software/MATLAB/2023b:/rds/easybuild/noarch/apps/software/MATLAB/2023b/bin:/sbin:/bin:/usr/sbin:/usr/bin:/usr/local/sbin:/opt/pbs/bin)

# %%
# !source /etc/profile.d/modules.sh && module load GDAL && which gdal_translate
# Out:
# /sw-eb/software/GDAL/3.10.0-foss-2024a/bin/gdal_translate

# %%
# !./01-run.sh
# Out:
# ./01-run.sh: line 57: gdalwarp: command not found
# ./01-run.sh: line 58: gdalwarp: command not found
# ./01-run.sh: line 59: gdalwarp: command not found
# ./01-run.sh: line 63: gdal_calc.py: command not found
# ./01-run.sh: line 63: gdal_calc.py: command not found
# ./01-run.sh: line 63: gdal_calc.py: command not found
# ./01-run.sh: line 63: gdal_calc.py: command not found
# ./01-run.sh: line 63: gdal_calc.py: command not found
# ./01-run.sh: line 63: gdal_calc.py: command not found
# ./01-run.sh: line 63: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ./01-run.sh: line 68: gdal_calc.py: command not found
# ...

# %%
# Check if it worked
# !which gdalwarp
# !which gdal_calc.py
# Out:
# /usr/bin/which: no gdalwarp in (/opt/jupyter/bin:/rds/easybuild/noarch/apps/software/MATLAB/2023b:/rds/easybuild/noarch/apps/software/MATLAB/2023b/bin:/sbin:/bin:/usr/sbin:/usr/bin:/usr/local/sbin:/opt/pbs/bin)
# /usr/bin/which: no gdal_calc.py in (/opt/jupyter/bin:/rds/easybuild/noarch/apps/software/MATLAB/2023b:/rds/easybuild/noarch/apps/software/MATLAB/2023b/bin:/sbin:/bin:/usr/sbin:/usr/bin:/usr/local/sbin:/opt/pbs/bin)
